# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
project_path='/content/gdrive/MyDrive/Colab Notebooks/Golpo Kothok GPT'

# %%
import sys
# Add the project path to sys.path to allow importing from utils.py
# project_path is defined in an earlier cell as '/content/gdrive/MyDrive/Colab Notebooks'
if project_path not in sys.path:
    sys.path.append(project_path)

# %%
import torch
import torch.nn as nn

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Load Data

# %%
import os
file_name = "data/training_data.txt"
dataset_file_path = os.path.join(project_path, file_name)

with open(dataset_file_path, "r", encoding="utf-8") as f:
    text_data = f.read()

print("Total number of character:", len(text_data))
# Out:
# Total number of character: 12633030

# %% [markdown]
# ### **Define GPT Configuration**

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,    # Vocabulary size
    "context_length": 512, # Context length (Original contex length in GPT 2  is 1024. For the sake of simplicity we used 256)
    "emb_dim": 768,         # Embedding dimension
    "n_heads": 12,          # Number of attention heads
    "n_layers": 12,         # Number of layers
    "drop_rate": 0.1,       # Dropout rate
    "qkv_bias": False,       # Query-Key-Value bias
    "key_dim": 768,
    "val_dim": 768
}

# %% [markdown]
# ### Tokenize using `tiktoken`

# %%
import tiktoken
tokenizer = tiktoken.get_encoding("gpt2")

# %% [markdown]
# ### Encode tokens

# %%
total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data))

print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# Characters: 12633030
# Tokens: 3049258

# %% [markdown]
# ### Define the token sequence for stopping detection

# %%
# Define the token sequence for <|book_end|> (for stopping detection)
END_SEQUENCE = tokenizer.encode("<|end|>", allowed_special={
    '<|start|>',
    '<|end|>',
    '<|title|>',
    '</|title|>'
})

print(f"<|book_end|> token sequence: {END_SEQUENCE}")
print(f"Length: {len(END_SEQUENCE)} tokens")
# Out:
# <|book_end|> token sequence: [27, 91, 437, 91, 29]
# Length: 5 tokens

# %%
def text_to_token_ids(text, tokenizer):
    # Adding your tokens to allowed_special
    encoded = tokenizer.encode(text, allowed_special={
        '<|start|>',
        '<|end|>',
        '<|title|>',
        '</|title|>'
    })

    encoded_tensor = torch.tensor(encoded).unsqueeze(0)  # add batch dimension
    return encoded_tensor



def token_ids_to_text(token_ids, tokenizer):
    if token_ids is None:
        raise ValueError("token_ids is None! Check your text_to_token_ids function.")
    flat = token_ids.squeeze(0)  # remove batch dimension
    return tokenizer.decode(flat.tolist())

# %% [markdown]
# ### Dataset and Dataloader

# %%
from torch.utils.data import Dataset, DataLoader


class GPTDataset(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []


        # Tokenize the entire text with special tokens
        token_ids = tokenizer.encode(txt, allowed_special={
            '<|start|>',
            '<|end|>',
            '<|title|>',
            '</|title|>'
        })


        # Use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]
            target_chunk = token_ids[i + 1: i + max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]


def create_dataloader(txt, batch_size=100, max_length=512,
                         stride=128, shuffle=True, drop_last=True,
                         num_workers=0):

    # Initialize the tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    # Create dataset
    dataset = GPTDataset(txt, tokenizer, max_length, stride)

    # Create dataloader
    dataloader = DataLoader( # torch.utils.data.DataLoader loads data from a Dataset in mini-batches, optionally shuffling, using multiple workers.
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers
    )

    return dataloader

# %% [markdown]
# ### Load Model

# %%
# Load checkpoint and resume training
def load_checkpoint(model,checkpoint_path):

    checkpoint = torch.load(checkpoint_path,map_location=torch.device("cpu"),weights_only=True,)

    model.load_state_dict(checkpoint['model_state_dict'])

    print('Model Loaded Successfully')

# %% [markdown]
# ### Generate Function

# %%
def generate(model, idx, max_new_tokens, context_size, temperature=0.0, top_k=None, eos_id=None,eos_sequence=None):
    # Loop: Get logits, and only focus on last time step
    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)
        logits = logits[:, -1, :]

        # Filter logits with top_k sampling
        if top_k is not None:
            # Keep only top_k values
            top_logits, _ = torch.topk(logits, top_k)
            min_val = top_logits[:, -1]
            logits = torch.where(logits < min_val, torch.tensor(float("-inf")).to(logits.device), logits)

        # Apply temperature scaling
        if temperature > 0.0:
            logits = logits / temperature

            # Apply softmax to get probabilities
            probs = torch.softmax(logits, dim=-1)  # (batch_size, context_len)

            # Sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1)  # (batch_size, 1)

        # Otherwise same as before: get idx of the vocab entry with the highest logits value
        else:
            idx_next = torch.argmax(logits, dim=-1, keepdim=True)  # (batch_size, 1)



        # Check for single-token EOS
        if eos_id is not None and idx_next.item() == eos_id: # Stop generating early if end-of-sequence token is encountered and eos_id is specified
            break


        # Check for multi-token EOS sequence
        if eos_sequence is not None:
            idx_list = idx[0].tolist()
            # Only check if we have enough tokens
            if len(idx_list) >= len(eos_sequence):
                last_n = idx_list[-len(eos_sequence):]


                if last_n == eos_sequence: # <|book_end|> detected. Stop generation"
                    break

        # Same as before: append sampled index to the running sequence

        idx = torch.cat((idx, idx_next), dim=1)  # (batch_size, num_tokens+1)

    return idx

# %%
def generate_story(test_no,model, tokenizer, output_dir, start_context=None, max_new_tokens=50, temperature=0.0, top_k=None):


        context_size = model.pos_emb.weight.shape[0]


        if start_context is None or start_context == "":

          start_context = "<|start|>"

          start_context_encoded = text_to_token_ids(start_context, tokenizer).to(device)


        with torch.no_grad():
            token_ids = generate(
                model=model, idx=start_context_encoded,
                max_new_tokens=max_new_tokens, context_size=context_size,
                temperature=temperature, top_k=top_k,
                eos_sequence=END_SEQUENCE

            )
        decoded_text = token_ids_to_text(token_ids, tokenizer)

        #decoded_text=decoded_text.replace("\n", " ")
        #print("Hello: \n",decoded_text,"\n\nHello\n\n")

        formatted_text = format_text(decoded_text)
        print(formatted_text)


        with open(f"{output_dir}/output_no_{test_no}_{temperature}_{top_k}_{max_new_tokens}.txt", "w", encoding="utf-8") as f:
            f.write(formatted_text)

# %%
import re
import textwrap

def format_text(text, width=80):
    # Remove all <|tag|> and </|tag|> tokens
    formatted_text = re.sub(r'</?\|[^|]+\|>', '', text)

    lines = formatted_text.split('\n')

    wrapped_lines = []
    for line in lines:
        if line.strip():
            wrapped_lines.append(textwrap.fill(line, width=width))
        else:
            wrapped_lines.append(line)

    return '\n'.join(wrapped_lines)

# %%
from utils import GPTModel
model = GPTModel(GPT_CONFIG_124M)
model.to(device)

checkpoint_dir = project_path+'/gpt_checkpoints'

checkpoint_file = 'checkpoint_V1_2_epoch_12_step_7931.pt'

checkpoint_path = os.path.join(checkpoint_dir, checkpoint_file)

# load the model
if os.path.exists(checkpoint_path):
        load_checkpoint(model, checkpoint_path)
        model.eval()
else:
    print('Model Not Exists')
# Out:
# Model Loaded Successfully

# %%
'''
prompt = [
    "Once a boy was walking",
    "There was a woman ",
    "A man found a dead body ",
    "A king can sacrifice for his people and kingdom.",
    "There was a city known for criminal activities.",
    "Deep in the jungle, an explorer discovered",
    "There was a village",
    "There was a jungle ",
    "A boy had a monkey"

    """<|start|>
<|title|>The Lost Treasure<|/title|>

Deep in the jungle, an explorer discovered"""
]

prompt_no=0
'''
output_dir= project_path+'/output'


total_test=10

for test in range(total_test):
  generate_story(test,model, tokenizer, output_dir, max_new_tokens=20000, temperature=1.2, top_k=3) # 1.2, 3
# Out:
# The Unyielding Flame of Courage
#
# Once upon a time, in a small town called Willow, nestled between the rolling
# hills and the lush greenery, the lush green mountains of Willowbrook. The town
# was home to a lush, unassuming, and the beautiful Victorian town of Elmswood.
# The town was a tight, green place where the rich lived in opulence and the air
# was thick with the scent of mystery. The town was known for its rich rich and
# the town, where it cherished, with people lived their lives in harmony and their
# tight-knit community.
#
# At the heart of the town stood a magnificent clockmaker, the Willowbrook was the
# town's mayor, Sarah, a renowned crumbled to the town's beloved mayor. Sarah was
# a kind-hearted artist, and she loved hearing the admiration of her loving life -
# the perfect mechanic and the paranormal investigator. Her younger daughter,
# Sarah, was known for her wit and withered redoufields, and her two often
# provided her the town a cleaner daughter named Sarah.
#
# Despite the challenges, the two families became close-knit family, attending
# local hospital with their love for nature and their passion for one another.
# Sarah, the eldest son, was a bright and intelligent girl who took care of her
# family and rock as a teacher at the local hospital gates. Emily, a talented
# artist, spent most of her time exploring the woods, while Emily was a nurturing
# interior, much like her father of flowers.
#
# One day, while Laura were working on her street, she came across an old, dusty
# book in her father's store. The children, Jessica, was a curious and supportive
# girl, who had recently retired from her family and was 22 years ago. Emily, was
# a bright and curious soul who seemed to have a teacher of her parents, who had
# recently lost his job at school in Willowbrook to start a new home. Emily, an
# intelligent and curious and intelligent young girl who lived just exploring the
# city as a janitor at her father. Daniel was a curious and adventurous boy, who
# loved exploring the city and bustle of his home. Emily, the boy, was a gentle
# man who loved exploring the vast and fields. Emily had a passion for literature,
# determination, and unwavering dedication to her two children and family.
#
# Daniel, the two quickly became the center of exploring the town, where they
# spent most of their lives and studying the beauty of their surroundings were
# known for over the gentle blacksmith. The house was a peaceful place, with
# people from the quiet streets of Willowbrook. The house was a grand Victorian
# mansion, with lush greenery, and a sprawling house that was rumored to be
# haunted by the paranormal family. The house had been a peaceful place, with the
# parents, who were known to be the guardians of Mrs. Thompson, was a quiet,style
# house with a beautiful flowers. She could no longer ignore the darkness of the
# house, and she couldn't think of the ghost of the ghostly woman, the mysterious
# stranger with the same age of mystery. The tragedy had been passed down through
# generations by, many stories of children who lived in peaceful lives with the
# younger generation of Mrs. Thompson.
#
# One evening, while walking through the house, she stumbled upon a hidden house,
# concealed in the rooms of her attic. The book was covered with an old and
# cryptic symbols etched in their tattered book. As she opened the box, she could
# see that the whispers persisted her parents could hear and move her to the
# deepest fears that seemed to them, and she couldn't believe that the whispers of
# the ghostly spirits haunting Willowbrook had been buried deep within the house,
# waiting to be haunted by a secret.
#
# Intrigued by the whispers, Emily finally found the parents, the younger man of
# the house, who seemed to be haunted by the whispers of the house, the whispers
# that seemed to lurked in the darkness. The house seemed to be in the midst of an
# abandoned house, as if it was a woman, the ghost of Willowbrook had been buried
# deep black for shadows. As Emily walked through the dimly lit house, she heard a
# faint sound that seemed to close to them, as if her parents were whispering in
# the shadows that had been buried deep within her house for house for so long.
#
# One evening, Emily stepped into her aunt's house, she tattered book and dusty to
# reach the house. The house seemed to be in the darkest corners of the house, as
# if someone had been trying for Detective Blackwood to find some way to uncover
# the truth behind the darkness that had taken her to her. The book was lined with
# an eerie aura of red, and her whole house seemed to piqued in the darkness that
# seemed to move her to the afterlife.
#
# As the house drew to an ancient tome, Detective Blackwood began to feel a
# growing sense of growing sense of unease. He gnarried to the walls of the house,
# and he discovered the whispers of the house were tormented by a grand piano, its
# walls filled with arcane glyph and arcane artifacts. As Detective Blackwood
# began to unravel the mystery behind the house, Detective Blackwood had been
# seeking a terrible repute and rituals that had been buried deep within the house
# for the walls of the house.
#
# Detective Blackwood, Emily, and Tom, now the three friends, decided to confront
# the house for horrors they had collected over her. As they delved deeper into
# the darkness, they began to notice strange occurrences, and whispers. The walls
# seemed to grow larger and more ins with the air grew louder, and the air around
# them crackled with a palpable sense of foreboding and darkness.
#
# John soon discovered the mansion's house, in fact, was a grand Victorian-style
# house with a massive walls, broken walls of Victorian walls, had been buried
# deep beneath the house for centuries. The walls of the house had house were
# empty, and the walls were covered in a grand Victorian-style mansion. As
# Detective Blackwood lay in the dimly lit chamber, Detective Blackwood was
# greeted by the ghostly manor and the spirit to do so.
#
# The spirits revealed that it had been the guardians of a manor house, with some
# of the ghostly death to the wealthy and powerful artifacts that had been trapped
# there for generations. The manor, ornatels, had been haunted by the dark
# energies of the house to find peace and abandoned house for so long.
#
# As Detective Blackwood lay in the dark house, Detective Blackwood had been a
# dangerous and harrowing challenge. The spirit had been the guardians of the
# tormented souls who had abandoned the house for over the manor and its haunted
# house for so long. But Detective Blackwood had not only emerged from the
# tormented souls of the tormented souls who had chosen to leave them for so long.
#
# In the end of the three trials and tribulations, Detective Blackwood, and
# Detective Blackwood had built a close friendship between the manor and his own
# wife, Detective Blackwood. As the sun set on the small, quaint townspeople
# gathered together on the outskirts of the house, the ghostly apparitions finally
# emerged from the shadows of the house, bearing of some secret that had been
# buried deep beneath its walls.
#
# As the friends stared out over the dusty house, the manor, the pair knew that
# their adventure had only just begun. Detective Blackwood, armed with the
# daunting task of summoning, had ulched the town of its dark past. He couldn't
# shake the feeling that he had to confront and the friends insecurities, but they
# also knew that the ghost of the house remained empty, and the ghost of tormented
# souls who had ensnared its walls.
#
# As the friends regrouped the dark past began to notice strange occurrences, they
# started to feel the darkness closing in around them, and the walls that had been
# bound to the town for generations.
#
# The pair discovered that the house had been abandoned for several years,
# including a man named Lord Ambrose, who had been orchestrating the house with
# the house for orchestrating a series of rituals and valuable artifacts.
#
# Arabella was determined to uncover the truth, hoping that the darkness that lay
# within its walls were buried deep within the walls of the house. As the pair
# delved deeper into the house, they began to notice strange occurrences, and
# unexplained events that seemed to close to them in around them.
#
# As the friends continued to search for clues that, the pair discovered that the
# mansion was far more sinister of the town's End. The house, it was time that it
# turned to the male nurses, had been a grand, that had house the guardians of the
# house for so long.
#
# The house, once a grand Victorian mansion had entered a dark and twisted,
# idyllic house, was now a symbol of the darkness that had enveloped the manor
# house for so long.
#
# Detective Hartwell, the mansion had haunted the house for over the mansion, had
# haunted the souls who had been haunted by the monstrous history of the victims.
# He had been trapped there for some time, and he had chosen to return to the
# haunted house, hoping that the darkness of the manor would finally find peace
# and closure to the supernatural world.
#
# Detective Blackwood, Detective Blackwood, was a man of great intellect and
# selflessness, who could tell the tale of Detective Blackwood and the tormented
# souls who had chosen to confront the darkness that had ensnared its walls in the
# house for so long after his men. As the darkness receded and the tormented souls
# of the victims of the victims, Detective Blackwood, lay in front of the
# darkness, was a testament to the courage and the unbreakable bond between
# friends and family of the younger man and family of Willowbrook.
#
#
#
#
# The Unyielding Flame of Courage
#
# In the sprawling metropolis of Neo-Tokyo, a city that never sleeps, the citizens
# lived in the heart of the city, a young woman named Lila, who was as kind-
# hearted, resident of resident, was the product of a renowned for socialite,
# working tirelessly to crack any computer. Her work was admired by everyone, and
# her nights were spent countless hours working tirelessly in a series of high-
# stakes chambers.
#
# Lila was a renowned botanist, a renowned creative woman of 20 years old files
# and trade, who had dedicated her life to the study of her 20th century England.
# Her passion for nature was ignited that she had a strangle prowess, and her work
# was the envy of an Tempest, which had spent countless meticulously planning a
# unique problem. The city's finest doctors were loved, as each member of the
# city's unique code was often referred to, and a culture that was both
# harmonious. However, the most select few days were numbered, a dark secret, a
# corporation - a shadowy organization that sought to exploit others as their own
# gain.
#
# As Lila grew older, she quickly developed a deep understanding of the world's
# political underworld. Her team consisted of five members: a woman named Lila, a
# former hacker and engineer, and her unparalleled expertise in various espionage
# and manipulation.
# 2. A mad scientist who possessed the ability to manipulate the city's digital
# infrastructure and algorithms that were counted, and the result of a series of
# illicit activities. These cyberterrorists were a closely working to manipulate
# the city's financial institutions, healthcare, and even the very technologies.
#
# Despite these trials and setbacks, Lila's team persevered, and set out to
# unravel the dark forces that lurked beneath its surface. They encountered
# ruthless henchmen, hostile tribes, and their oppressive grip on power to the
# world around them. The team's ultimate goal was to unravel the mystery of the
# cyber cyber attacks and put an end to their nefarious machinations.
#
# As Lila continued her investigation, she found herself drawn into the Shadow
# Syndicate's web. She began to unravel the web of corruption and corruption that
# seemed to grow even deeper into the heart of the city, and its secrets hidden
# beneath the network.
#
# One day, while on a seemingly ordinary man arose from a mysterious figure known
# as "The Shadow." The Shadow had a dark secret project, a plan that could take
# control of the manipulation of the city and bend the vulnerable to their will.
# According to the sinister influence of the city and its creators, The Shadow was
# a shape-shifting landscape, and the Shadow Syndicate had sought to take control
# of it to her own twisted vision.
#
# Lila knew that she couldn't do whatever to save her team and the Syndicate's
# life, but the task was determined to do whatever it took to save her brother and
# the city from the clutches of evil cyberterrorism. She began to delved deeper
# into the heart of the corporation's operations, hoping to find a cure for the
# darkness that threatened to consume them all.
#
# As Lila delved deeper into her investigation, she began to uncover a web of
# intrigue that lies not only a tangled web of corruption but also a lies, a
# tangled network of tunnels that sought to challenge their creation. The Shadow
# Syndicate's ultimate goal was to bring about to light and the darkest corners of
# the metropolis, to do their ultimate goal, all in order to stop them against the
# darkness that threatened to consume their city from the shadows.
#
# Armed with the daunting task of choice, Lila set out on a dangerous journey to
# the Shadow Syndicate's hidden lair, where Lila and her team faced off against
# the Shadow Syndicate's most powerful minions. Along the way, they encountered a
# diverse cast of characters, each of whom were willing to help them confront the
# darkness that threatened to consume it.
#
# Along her journey, Lila encounters a series of trials and deadly traps,
# including a shape-shifting landscape, and malevolent force that sought to thwart
# its quest in their goal: to save the city and enslave all of darkness.
#
# As Lila continued her investigation, her skills, and Lila discovered the true
# essence of the city and the vulnerable to the darkness that threatened to
# consume it. Along the way, Lila discovered a hidden chamber, deep beneath the
# city of an ancient, gnarled with the essence of the city and the collective
# wisdom of the human heart and the heroes who had ensed there.
#
# With the artifact in her possession, Lila and her companions set out on a
# perilous journey, deep within the heart of the city, where the darkness that
# threatened to consume them all. The battle raged on, with both parties vying for
# control, as the heroes fought valiantly against the darkness that threatened to
# consume them all hope and the world.
#
# And so, the shadows of the city continued to unfold, its people filled with a
# sense of hope and determination that lies in the face of adversity. The story of
# Lila and her quest for the Shadows of the Lost Relic became a legend, passed
# down through generations as generations, a testament to the power of the human
# spirit, and a reminder that even in the darkest of times, there is always hope,
# and a chance for those who stand together in the darkness that threatened to
# consume the city that lies within each heart and within its walls.
#
#
#
#
# The Last Breath
#
# Once upon a time, in a small town nestled between the rolling hills of the
# verdant valley, a peculiar event was brewing. The town, renowned for its
# picturesque landscapes, had a reputation for being joy, and the pride and joy of
# his work were spent for the townsfolk around a reclusive and tight-knit
# community.
#
# Leo was a man of average, a hardworking and dedicated scientist, and his ability
# to solve even the most complex mysteries within his town. He had a vast
# collection of books and books who had lost his time in the town, from different
# backgrounds and working at the local library. It was a place that stood at the
# heart of the community, a place where the young boy named Ethan, could explore
# and find little more.
#
# One day, while on a seemingly ordinary morning, Ethan stumbled upon an old,
# abandoned house with no return home from the town. Intrigued, he followed the
# boy and ventured into the old house, only to find the town's mysterious
# flickering light. As he ventured further into the woods, he heard a faint and
# ominous sound that seemed to whisper about him. It was haunting, and Ethan
# reached out and found himself in an abandoned room, followed by a flickering
# light that read, and the sound of something sinister.
#
# Unbeknownst to Ethan, the stranger began to notice signs of dread. He sipped
# through the dark, and as he did so, he was suddenly struck by a group of armed
# henchmen who seemed to know their presence. Among them was a man named Mr.
# Johnson, a villain in the community center.
#
# Unbeknownst to Mr. Blackwood, a group of thieves who were in town's darkest
# secrets. They knew exactly what they were doing, and they were out of hiding a
# room at the walls of the town, waiting for any chance of safety.
#
# As they ventured further into the gang, they encountered a group of armed
# guards, each more deadly than the last. They were also known as the gang of gang
# members, led by a ruthless treasure hunter named Lucinda, the gang leader, and
# the gang leader of the gang members.
#
# The ensuing battle raged on, with the gang members fighting valiant skills and
# determination to protect the secret recipe and bring them hurt. As the gang
# descended to their homes, they were greeted by a series of hilarious incidents,
# each one more hilarious with each part of them.
#
# In the ensuing battle, Ethan was gravely injured. As the sun began to set, Ethan
# wrenched his men, summoning a bullet that stood before them, his men were
# defeated by the darkness that had enveloped their town, and turned to an end.
#
# As he stood before the gang, the gang exchanged a mixture of surprise. The gang,
# turned their attention to the battle, and it was clear that of the Sunset Valley
# Comedy had taken hold of the town to the outlaw.
#
# The tension was palpable for the three friends and the gang, but they couldn't
# help but feel a deep sense, as the weight of them began to take down to the
# safety and focused of the seemingly idyllic town of them together around the
# black.
#
# As Ethan reached the bell of the gang's lair, he discovered a hidden compartment
# in the under the walls of the gold and precious rituals. The gang, inside a
# hidden lair, turned their attention to the gold and gold killer, carefully
# examining the remaining Blackwood and tumbled to dust in the shadows, bearing
# the remaining gang.
#
# As Ethan slept the gold and battered bodies of the gang, he couldn't think of
# the elusive gang's under the darkness that lay in the shadows of the house.
# Ethan, driven by his curiosity and his unwavering determination, finally put his
# chance to safety and put an end to the gang's machinations.
#
# With no other options on their trail, the gang banded together to make their way
# through the treacherous terrain of Sunset Valley. Eventually, they discovered a
# hidden treasure deep beneath the town's gold and abandoned building, which led
# to a trail of the gold and ancient artifacts that had been cast by the gold and
# the crystal.
#
# As they ventured further into the lair of darkness, the lair of Clayton
# Blackwood had turned his back to the safety switch, and he was able to escape
# the shadows, and the three friends could finally begin.
#
# With no clues that lay in their hands on the gang, Ethan and his companions set
# out on, determined to reach the darkness that had been placed upon them for so
# long.
#
# As they stepped inside the cabin, they could see a close friend and loyal side
# by the shadows that had been torn between them, and that had been trapped there
# for many years.
#
# And so, the legend of Ethan and the golden compass was one of a young girl, a
# testament to her wits, determination, and the indomitable spirit of her beloved
# golden hair and the innocent heart of darkness that had been cast upon them for
# so long, and there was still room for Ethan and his men to fight for their lives
# in the world.
